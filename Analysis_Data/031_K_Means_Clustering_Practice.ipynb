# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Get the Data

# %% [markdown]
# ** Read in the College_Data file using read_csv. Figure out how to set the first column as the index.**

# %%
df = pd.read_pickle('PAT_3415_wref/PAT_3415_wref_2023-08-23.pkl')


y=df['Class']
df.drop('Class',inplace=True,axis=1)
df
# Out:
#              0         1         2         3         4         5         6   \
# GA1    0.483715  0.265764 -0.119434 -0.048157 -0.179256 -0.155573  1.187963
# GA2    0.398606  0.028651 -0.203806 -0.117415 -0.136427 -0.114856  0.588441
# GA3    0.043357  0.010885 -0.104572 -0.153744 -0.182513 -0.102815  0.523810
# GA4    0.410730  0.080677  0.036813  0.046381 -0.096244 -0.080055 -0.080726
# GA5   -0.143545  0.366892  0.107602 -0.191617 -0.166783 -0.030808  1.012558
# ...         ...       ...       ...       ...       ...       ...       ...
# HLG14 -0.817090 -1.327095 -0.533528 -0.277863 -0.369859 -0.155220 -3.180712
# HLG15 -0.891595 -0.966441 -0.521640 -0.413265 -0.386647 -0.248881 -3.857659
# HLG16 -0.986400 -1.172226  0.090839 -0.226294 -0.134856 -0.048451 -3.553981
# HLG17 -0.527283 -0.458474 -0.149502 -0.201963 -0.093792 -0.110353 -3.402531
# HLG18 -0.909549 -0.687828 -0.136858 -0.044270  0.050755  0.285514 -2.379198
#
#              7         8         9   ...        20        21        22  \
# GA1    0.952131 -0.086996 -0.397896  ... -0.063387 -0.262305 -0.323652
# GA2    0.499296 -0.328895 -0.367832  ... -0.313107 -0.438148 -0.385843
# GA3    0.663739 -0.045354 -0.133836  ...  0.126345  0.809905  0.266149
# GA4   -0.129069 -0.340858 -0.052157  ...  0.006090  0.984634  0.482303
# GA5    0.869969  0.159457 -0.519511  ... -0.120698  0.458651  0.248589
# ...         ...       ...       ...  ...       ...       ...       ...
# HLG14 -3.586907 -2.039388 -1.878885  ... -1.233885 -1.501601 -1.171114
# HLG15 -3.783381 -1.582642 -1.449072  ... -1.079907 -0.846336 -0.370741
# HLG16 -3.698886 -1.380141 -0.985199  ... -1.195962 -0.639447 -0.436414
# HLG17 -3.229067 -1.917119 -1.246712  ... -1.344066 -0.738237 -0.382400
# HLG18 -2.333656 -1.630201 -1.335235  ... -1.260918 -0.444553 -0.070491
#
#              23        24        25        26        27        28        29
# GA1   -0.308666 -0.591139 -0.389984  0.026109 -0.020250  0.113928  0.026257
# GA2   -0.261361 -0.386349 -0.354296 -0.073311 -0.142873 -0.045190  0.021992
# GA3   -0.036997 -0.131652 -0.203400  0.007803 -0.021141  0.132494  0.046397
# GA4    0.260356 -0.220176 -0.091140 -0.056507 -0.014549  0.051525  0.017754
# GA5   -0.063716 -0.572379 -0.618667 -0.166705 -0.059766 -0.031125 -0.044360
# ...         ...       ...       ...       ...       ...       ...       ...
# HLG14 -1.202723 -0.023732 -0.120402  0.034683 -0.434207  0.173213 -0.045776
# HLG15 -0.215898 -0.523800 -0.406407 -0.049618 -0.170514  0.229267  0.289204
# HLG16 -0.202022 -0.253749 -0.075727  0.114317  0.139163  0.266820  0.302262
# HLG17 -0.365429  0.145283  0.352366 -0.048786  0.160611  0.382168  0.202780
# HLG18 -0.239631  0.381152  0.182001 -0.153096 -0.140565  0.306024  0.199339
#
# [492 rows x 30 columns]

# %% [markdown]
# **Check the head of the data**

# %%
# Use the elbow method to find a good number of clusters
inertia = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, random_state=42)
    kmeans.fit(df)
    inertia.append(kmeans.inertia_)

plt.plot(range(1, 11), inertia, marker='o')
plt.xlabel('Number of Clusters')
plt.ylabel('Inertia')
plt.title('Elbow Method')
plt.show()
# Out:
# Cannot execute code, session has been disposed. Please try restarting the Kernel.
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ** Check the info() and describe() methods on the data.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 492 entries, GA1 to HLG18
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       492 non-null    float32
#  1   1       492 non-null    float32
#  2   2       492 non-null    float32
#  3   3       492 non-null    float32
#  4   4       492 non-null    float32
#  5   5       492 non-null    float32
#  6   6       492 non-null    float32
#  7   7       492 non-null    float32
#  8   8       492 non-null    float32
#  9   9       492 non-null    float32
#  10  10      492 non-null    float32
#  11  11      492 non-null    float32
#  12  12      492 non-null    float32
#  13  13      492 non-null    float32
#  14  14      492 non-null    float32
#  15  15      492 non-null    float32
#  16  16      492 non-null    float32
#  17  17      492 non-null    float32
#  18  18      492 non-null    float32
#  19  19      492 non-null    float32
#  20  20      492 non-null    float32
#  21  21      492 non-null    float32
#  22  22      492 non-null    float32
#  23  23      492 non-null    float32
#  24  24      492 non-null    float32
#  25  25      492 non-null    float32
#  26  26      492 non-null    float32
#  27  27      492 non-null    float32
#  28  28      492 non-null    float32
#  29  29      492 non-null    float32
# dtypes: float32(30)
# memory usage: 61.5+ KB
